# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# ============================================================
# GITHUB SETUP - Run in Colab
# ============================================================

from pathlib import Path
import os

# Project root
PROJECT_ROOT = Path("/content/drive/MyDrive/ai_fashion_assistant_v2")
# %cd {PROJECT_ROOT}

# Git konfigürasyonu
# !git config --global user.name "Your Name"
# !git config --global user.email "your.email@example.com"

# Git init (eğer yapılmadıysa)
# !git init

# Add remote (senin GitHub repo URL'ini koy)
# !git remote add origin https://github.com/yourusername/ai-fashion-assistant-v2.git

# Or use SSH (recommended):
# !git remote add origin git@github.com:yourusername/ai-fashion-assistant-v2.git

# Verify remote
# !git remote -v
# Out:
# /content/drive/MyDrive/ai_fashion_assistant_v2
# Reinitialized existing Git repository in /content/drive/MyDrive/ai_fashion_assistant_v2/.git/
# error: remote origin already exists.
# origin	https://github.com/yourusername/ai-fashion-assistant-v2.git (fetch)
# origin	https://github.com/yourusername/ai-fashion-assistant-v2.git (push)

# %%
# Add files
# !git add README.md
# !git add requirements.txt
# !git add .gitignore
# !git add Makefile
# !git add src/schema.py
# !git add src/config.py
# !git add src/__init__.py
# !git add notebooks/phase0_setup/00_project_initialization.ipynb

# Commit
# !git commit -m "🚀 Initial commit: Project structure and SSOT schema"

# Push (ilk kez)
# !git branch -M main
# !git push -u origin main
# Out:
# On branch main
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	api/
# 	data/
# 	notebooks/phase0_setup/github_setup.ipynb
# 	tests/
# 	ui/
#
# nothing added to commit but untracked files present (use "git add" to track)
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# KODU ekle (data/ EKLEME!)
# !git add api/
# !git add tests/
# !git add ui/
# !git add notebooks/phase0_setup/github_setup.ipynb

# (Guide'daki ilk commit dosyaları sende varsa bunları da ekle)
# !git add README.md
# !git add requirements.txt
# !git add .gitignore
# !git add Makefile
# !git add src/schema.py
# !git add src/config.py
# !git add src/__init__.py
# !git add notebooks/phase0_setup/00_project_initialization.ipynb

# Kontrol
# !git status
# Out:
# On branch main
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	new file:   api/__init__.py
# 	new file:   api/endpoints/__init__.py
# 	new file:   notebooks/phase0_setup/github_setup.ipynb
# 	new file:   tests/__init__.py
# 	new file:   ui/__init__.py
# 	new file:   ui/components/__init__.py
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	data/

# %%
# !git commit -m "🚀 Initial commit: Project structure and SSOT schema"
# Out:
# [main cf69629] 🚀 Initial commit: Project structure and SSOT schema
#  6 files changed, 1 insertion(+)
#  create mode 100644 api/__init__.py
#  create mode 100644 api/endpoints/__init__.py
#  create mode 100644 notebooks/phase0_setup/github_setup.ipynb
#  create mode 100644 tests/__init__.py
#  create mode 100644 ui/__init__.py
#  create mode 100644 ui/components/__init__.py

# %%
# !git branch -M main
# !git push -u origin main
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# Install gh
# !curl -fsSL https://cli.github.com/packages/githubcli-archive-keyring.gpg | sudo dd of=/usr/share/keyrings/githubcli-archive-keyring.gpg
# !echo "deb [arch=$(dpkg --print-architecture) signed-by=/usr/share/keyrings/githubcli-archive-keyring.gpg] https://cli.github.com/packages stable main" | sudo tee /etc/apt/sources.list.d/github-cli.list > /dev/null
# !sudo apt update
# !sudo apt install gh -y

# Login
# !gh auth login
# Out:
# 4+1 records in
# 4+1 records out
# 2270 bytes (2.3 kB, 2.2 KiB) copied, 0.191819 s, 11.8 kB/s
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://cli.github.com/packages stable InRelease [3,917 B]
# Hit:3 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Hit:7 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:9 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [6,411 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/multiverse amd64 Packages [69.3 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,966 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,598 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy-backports/universe amd64 Packages [40.7 kB]
# Fetched 12.3 MB in 4s (3,021 kB/s)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 3 packages can be upgraded. Run 'apt list --upgradable' to see them.
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# gh is already the newest version (2.83.2).
# 0 upgraded, 0 newly installed, 0 to remove and 3 not upgraded.
# 78? Where do you use GitHub?  [Use arrows to move, type to filter]
# > GitHub.com
#   Other
# 788? Where do you use GitHub? GitHub.com
# 78? What is your preferred protocol for Git operations on this host?  [Use arrows to move, type to filter]
# > HTTPS
#   SSH
# 788? What is your preferred protocol for Git operations on this host? HTTPS
# ? Authenticate Git with your GitHub credentials? (Y/n) 7^C

# %%
# !gh auth login --hostname github.com --web --git-protocol https
# Out:
# ? Authenticate Git with your GitHub credentials? (Y/n) 7^C

# %%
# !printf "Y\n" | gh auth login --hostname github.com --web --git-protocol https
# Out:
# ! First copy your one-time code: C244-0E4C
# Open this URL to continue in your web browser: https://github.com/login/device
# ^C
#
# ! First copy your one-time code: 0C73-BA21
# Open this URL to continue in your web browser: https://github.com/login/device
# ✓ Authentication complete.
# - gh config set -h github.com git_protocol https
# ✓ Configured git protocol
# ! Authentication credentials saved in plain text
# ✓ Logged in as haticebaydemir

# %%
# %cd /content/drive/MyDrive/ai_fashion_assistant_v2
# !git push -u origin main
# Out:
# /content/drive/MyDrive/ai_fashion_assistant_v2
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# %cd /content/drive/MyDrive/ai_fashion_assistant_v2

# !gh auth status -h github.com
# !gh auth setup-git
# !git remote -v
# Out:
# /content/drive/MyDrive/ai_fashion_assistant_v2
# github.com
#   ✓ Logged in to github.com account haticebaydemir (/root/.config/gh/hosts.yml)
#   - Active account: true
#   - Git operations protocol: https
#   - Token: gho_************************************
#   - Token scopes: 'gist', 'read:org', 'repo'
# origin	https://github.com/yourusername/ai-fashion-assistant-v2.git (fetch)
# origin	https://github.com/yourusername/ai-fashion-assistant-v2.git (push)

# %%
# %cd /content/drive/MyDrive/ai_fashion_assistant_v2
# !git remote set-url origin https://github.com/haticebaydemir/ai-fashion-assistant-v2.git
# !git remote -v
# Out:
# /content/drive/MyDrive/ai_fashion_assistant_v2
# origin	https://github.com/haticebaydemir/ai-fashion-assistant-v2.git (fetch)
# origin	https://github.com/haticebaydemir/ai-fashion-assistant-v2.git (push)

# %%
# !gh auth setup-git

# %%
# !git push -u origin main
# Out:
# Enumerating objects: 21, done.
# Counting objects: 100% (21/21), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (17/17), done.
# Writing objects: 100% (21/21), 20.34 KiB | 293.00 KiB/s, done.
# Total 21 (delta 3), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (3/3), done.
# To https://github.com/haticebaydemir/ai-fashion-assistant-v2.git
#  * [new branch]      main -> main
# Branch 'main' set up to track remote branch 'main' from 'origin'.
